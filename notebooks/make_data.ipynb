# %%
import pandas as pd
import numpy as np
import os
import sys
import scanpy as sc

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/DGC/data/tabula_sapiens/TabulaSapiens.h5ad"
data = sc.read_h5ad(fpath)
data
# Out:
# AnnData object with n_obs × n_vars = 483152 × 58870
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi', '_training_mode', 'compartment_colors', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_colors', 'donor_method_colors', 'hvg', 'method_colors', 'neighbors', 'organ_tissue_colors', 'sex_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     layers: 'decontXcounts', 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
data.obs.head()
# Out:
#                                        organ_tissue method donor  \
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1        Liver    10X  TSP6
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1        Liver    10X  TSP6
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1        Liver    10X  TSP6
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1        Liver    10X  TSP6
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1        Liver    10X  TSP6
#
#                                        anatomical_information  n_counts_UMIs  \
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1                    nan         7633.0
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1                    nan         2858.0
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1                    nan         7787.0
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1                    nan        10395.0
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1                    nan         6610.0
#
#                                         n_genes  \
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1     2259
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1     1152
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1     2983
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1     2598
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1     2125
#
#                                                          cell_ontology_class  \
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1                            macrophage
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1                              monocyte
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1  endothelial cell of hepatic sinusoid
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1                            macrophage
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1                  liver dendritic cell
#
#                                             free_annotation  \
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1  Monocyte/Macrophage
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1             Monocyte
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1          Endothelial
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1  Monocyte/Macrophage
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1       Dendritic cell
#
#                                         manually_annotated  compartment gender
# AAACCCACACTCCTGT_TSP6_Liver_NA_10X_1_1                True       immune   male
# AAACGAAGTACCAGAG_TSP6_Liver_NA_10X_1_1                True       immune   male
# AAACGCTCAACGGCTC_TSP6_Liver_NA_10X_1_1                True  endothelial   male
# AAAGAACAGCCTCTTC_TSP6_Liver_NA_10X_1_1                True       immune   male
# AAAGAACGTAGCACAG_TSP6_Liver_NA_10X_1_1                True       immune   male

# %%
celltypes = ['fibroblast',  'hematopoietic stem cell']

tissue_blacklist = ['Uterus', 
                    'Salivary_Gland', 
                    'Pancreas', 
                    'Lymph_Node', 
                    'Lung', 
                    'Liver', 
                    'Eye',
                    ]

mask = (data.obs['cell_ontology_class'].isin(celltypes) & ~data.obs['organ_tissue'].isin(tissue_blacklist))
pdf = data[mask].copy()

cellmap = {
    'fibroblast' : 'FB',
    'hematopoietic stem cell' : 'HSC',
}

pdf.obs['celltype'] = pdf.obs['cell_ontology_class'].map(cellmap)

pdf
# Out:
# AnnData object with n_obs × n_vars = 27346 × 58870
#     obs: 'organ_tissue', 'method', 'donor', 'anatomical_information', 'n_counts_UMIs', 'n_genes', 'cell_ontology_class', 'free_annotation', 'manually_annotated', 'compartment', 'gender', 'celltype'
#     var: 'gene_symbol', 'feature_type', 'ensemblid', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: '_scvi', '_training_mode', 'dendrogram_cell_type_tissue', 'dendrogram_computational_compartment_assignment', 'dendrogram_consensus_prediction', 'dendrogram_tissue_cell_type', 'donor_colors', 'donor_method_colors', 'hvg', 'method_colors', 'neighbors', 'organ_tissue_colors', 'sex_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_scvi', 'X_scvi_umap', 'X_umap'
#     layers: 'decontXcounts', 'raw_counts'
#     obsp: 'connectivities', 'distances'

# %%
# add a cell ID

pdf.obs['record_id'] = list(range(1, len(pdf.obs)+1))
pdf.obs['cell_id'] = pdf.obs['celltype'].astype(str) + "_" + pdf.obs['record_id'].astype(str)
pdf.obs.head()
# Out:
#                                          organ_tissue method donor  \
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1      Trachea    10X  TSP6
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1      Trachea    10X  TSP6
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1      Trachea    10X  TSP6
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1      Trachea    10X  TSP6
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1      Trachea    10X  TSP6
#
#                                          anatomical_information  \
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1                    nan
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1                    nan
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1                    nan
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1                    nan
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1                    nan
#
#                                           n_counts_UMIs  n_genes  \
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1        17016.0     4353
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1         8717.0     2673
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1        14208.0     3610
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1         5770.0     2117
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1        16684.0     3954
#
#                                          cell_ontology_class free_annotation  \
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1          fibroblast      fibroblast
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1          fibroblast      fibroblast
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1          fibroblast      fibroblast
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1          fibroblast      fibroblast
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1          fibroblast      fibroblast
#
#                                           manually_annotated compartment  \
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1                True     stromal
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1                True     stromal
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1                True     stromal
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1                True     stromal
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1                True     stromal
#
#                                          gender celltype  record_id cell_id
# AAAGAACTCCTACCGT_TSP6_Trachea_NA_10X_1_1   male       FB          1    FB_1
# AAAGTGACATCATGAC_TSP6_Trachea_NA_10X_1_1   male       FB          2    FB_2
# AACCACACACTCCGGA_TSP6_Trachea_NA_10X_1_1   male       FB          3    FB_3
# AACGGGACAGAGATGC_TSP6_Trachea_NA_10X_1_1   male       FB          4    FB_4
# AACGTCACACGCGCAT_TSP6_Trachea_NA_10X_1_1   male       FB          5    FB_5

# %% [markdown]
# # preprocess

# %%
sc.pp.normalize_total(pdf, target_sum=1e4)
sc.pp.log1p(pdf)

# %%
outpath = "/nfs/turbo/umms-indikar/shared/projects/adaptive_sampling/data/tabula_sapiens_filtered.h5ad"
pdf.write(outpath)
print('done')
# Out:
# done

# %%
# download the pbmc3k dataset
